# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# %%
data = pd.read_csv('data/우체국금융개발원_우체국 금융 사기계좌 정보_20241231.csv', encoding='cp949')

# %%
data
# Out:
#       연령대 피해자 성별  최초 접수년  최초 접수월  피해자계좌_피해(송금)액         사기유형             사칭기관  \
# 0      20      남    2022       1         990000       사건연루조사       경찰. 검찰. 법원
# 1      20      남    2022       1         300000       사건연루조사       경찰. 검찰. 법원
# 2      30      남    2022       1        1000000  지인사칭(메신저피싱)               개인
# 3      30      여    2022       1      118000000       사건연루조사       경찰. 검찰. 법원
# 4      40      여    2022       1       33800000      기존대출 상환  할부금융(카드사 및 캐피탈)
# ...   ...    ...     ...     ...            ...          ...              ...
# 2579   40      여    2024      12       20000000    대출실행 후 상환             저축은행
# 2580   30      남    2024      12      109450000           기타   우체국. 전화국. 택배회사
# 2581   50      남    2024      12       46800000      기존대출 상환             시중은행
# 2582   20      남    2024      12       82000000           기타             시중은행
# 2583   60      남    2024      12       14500000      기존대출 상환             시중은행
#
#      피해구제 신청사유 접근매체
# 0        보이스피싱   전화
# 1        보이스피싱   전화
# 2        보이스피싱   문자
# 3        보이스피싱   전화
# 4         일반대출   문자
# ...        ...  ...
# 2579      일반대출   전화
# 2580      일반대출   전화
# 2581      일반대출  메신저
# 2582      일반대출   전화
# 2583      일반대출  메신저
#
# [2584 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2584 entries, 0 to 2583
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   연령대            2584 non-null   int64
#  1   피해자 성별         2584 non-null   object
#  2   최초 접수년         2584 non-null   int64
#  3   최초 접수월         2584 non-null   int64
#  4   피해자계좌_피해(송금)액  2584 non-null   int64
#  5   사기유형           2584 non-null   object
#  6   사칭기관           2584 non-null   object
#  7   피해구제 신청사유      2584 non-null   object
#  8   접근매체           2584 non-null   object
# dtypes: int64(4), object(5)
# memory usage: 181.8+ KB

# %%
gender_avg = data.groupby('성별')['피해송금액'].mean().reset_index()

# %%
data.columns
# Out:
# Index(['연령대', '피해자 성별', '최초 접수년', '최초 접수월', '피해자계좌_피해(송금)액', '사기유형', '사칭기관',
#        '피해구제 신청사유', '접근매체'],
#       dtype='object')

# %%
data.columns = ['연령대','성별','최초접수년도',
                '최초접수월','피해송금액','사기유형','사칭기관',
                '피해구제신청사유','접근매체']

# %%
data
# Out:
#       연령대 성별  최초접수년도  최초접수월      피해송금액         사기유형             사칭기관 피해구제신청사유  \
# 0      20  남    2022      1     990000       사건연루조사       경찰. 검찰. 법원    보이스피싱
# 1      20  남    2022      1     300000       사건연루조사       경찰. 검찰. 법원    보이스피싱
# 2      30  남    2022      1    1000000  지인사칭(메신저피싱)               개인    보이스피싱
# 3      30  여    2022      1  118000000       사건연루조사       경찰. 검찰. 법원    보이스피싱
# 4      40  여    2022      1   33800000      기존대출 상환  할부금융(카드사 및 캐피탈)     일반대출
# ...   ... ..     ...    ...        ...          ...              ...      ...
# 2579   40  여    2024     12   20000000    대출실행 후 상환             저축은행     일반대출
# 2580   30  남    2024     12  109450000           기타   우체국. 전화국. 택배회사     일반대출
# 2581   50  남    2024     12   46800000      기존대출 상환             시중은행     일반대출
# 2582   20  남    2024     12   82000000           기타             시중은행     일반대출
# 2583   60  남    2024     12   14500000      기존대출 상환             시중은행     일반대출
#
#      접근매체
# 0      전화
# 1      전화
# 2      문자
# 3      전화
# 4      문자
# ...   ...
# 2579   전화
# 2580   전화
# 2581  메신저
# 2582   전화
# 2583  메신저
#
# [2584 rows x 9 columns]

# %%
# 1. 성별에 따른 평균 피해 금액 비교

# %%
rcParams['font.family'] = 'AppleGothic'

# %%
plt.figure(figsize=(6, 4))
plt.bar(gender_avg['성별'], gender_avg['피해송금액'], color=['green','blue','pink'])
plt.xlabel('성별')
plt.ylabel('평균 피해 금액 (원)')
plt.title('성별에 따른 평균 피해 금액')
plt.show()

# %%
# 연령대별 사기 유형 분포 분석

# %%
cross_tab = pd.crosstab(data['연령대'], data['사기유형'])

# %%
cross_tab
# Out:
# 사기유형  가족납치.상해 협박  개인정보유출방지, 보안강화  개인정보유출방지. 보안강화  기존대출 상환  기타  \
# 연령대
# 0              0               0               0        1   1
# 10             0               0               0        0   0
# 20             0               0               3       12  22
# 30             3               0               0       54  35
# 40             1               2               2       95  55
# 50             2               4               2      141  85
# 60             2               2               0       62  77
# 70             0               1               1        5  14
# 80             0               0               0        1   3
#
# 사기유형  대출수수료 요구(보증료, 공탁 등)  대출수수료 요구(보증료. 공탁 등)  대출실행 후 상환  미배송 및 공과금연체 관련  \
# 연령대
# 0                       0                    0          0               0
# 10                      0                    0          0               0
# 20                     11                    2          3               0
# 30                      4                    5         19               0
# 40                     14                   10         21               0
# 50                     15                    1         53               5
# 60                      5                    1         26               3
# 70                      3                    0          7               1
# 80                      0                    0          0               0
#
# 사기유형  사건연루조사  지인사칭(메신저피싱)
# 연령대
# 0          2            0
# 10         2            0
# 20       146            5
# 30        12           12
# 40        11           41
# 50        18          486
# 60        63          584
# 70        19          248
# 80         3           35
